# %% [markdown]
# ## IBM Data Science Professional Certificate - Capstone project

# %% [markdown]
# A project by Jahnavi Prasad Srirampurapu

# %%
import pandas as pd
import numpy as np

print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
